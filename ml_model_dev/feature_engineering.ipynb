# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
sql = """
    SELECT
    *
    FROM personal_finance.transactions
"""

df = pd.read_gbq(sql, dialect='standard', project_id='rasmus-prod', progress_bar_type='tqdm')
df.to_csv('bq_data.csv', index=False)
# Out:
# /Users/rasmus/opt/miniconda3/envs/my_finance/lib/python3.10/site-packages/google/cloud/bigquery/table.py:2155: UserWarning: A progress bar was requested, but there was an error loading the tqdm library. Please install tqdm to use the progress bar functionality.
#   record_batch = self.to_arrow(

# %%
df =pd.read_csv('bq_data.csv')
display(df)
print(df.info())
# Out:
#             date commit_date                              receiver  amount  \
# 0     2023-04-26  2023-05-03                                   NaN   -2.00
# 1     2023-04-20  2023-05-03                                   H M  -39.99
# 2     2023-04-24  2023-05-03                               STADIUM  -66.48
# 3     2023-04-16  2023-05-03                             KLARNA AB  -43.94
# 4     2023-04-12  2023-05-03                             KLARNA AB -221.30
# ...          ...         ...                                   ...     ...
# 1188  2023-03-06  2023-04-04                SEPPÄLÄ SEIJA TUULIKKI   25.00
# 1189  2023-03-21  2023-04-04             IKEA VANTAA IF CUSTOMER R   -9.68
# 1190  2023-03-20  2023-04-04             K-CITYMARKET ESPOO LEPPAV  -75.68
# 1191  2023-03-10  2023-04-04           MOBILEPAY KATARIINA SEPPÄLÄ  100.00
# 1192  2023-03-20  2023-04-04  MOBILEPAY SANNA MAARIT MARJA HEIKKIL   48.00
#
#              category commit_file_id
# 0       UNCATEGORIZED            POP
# 1     HOUSEHOLD-ITEMS            POP
# 2             HOBBIES            POP
# 3     HOUSEHOLD-ITEMS            POP
# 4       UNCATEGORIZED            POP
# ...               ...            ...
# 1188     OTHER-INCOME            POP
# 1189             FOOD            POP
# 1190             FOOD            POP
# 1191     OTHER-INCOME            POP
# 1192     OTHER-INCOME            POP
#
# [1193 rows x 6 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1193 entries, 0 to 1192
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            1193 non-null   object
#  1   commit_date     1193 non-null   object
#  2   receiver        1141 non-null   object
#  3   amount          1193 non-null   float64
#  4   category        1181 non-null   object
#  5   commit_file_id  1193 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 56.0+ KB
# None

# %% [markdown]
# # Priors

# %%
df_prior = df.copy()
rows = df_prior.shape[0]
df_prior = df_prior.groupby(['category']).agg(count=('category', 'count')).reset_index()
df_prior['prior'] = df_prior['count'] / rows
display(df_prior)
df_prior.sort_values(by='count', inplace=True, ascending=False)

plt.figure(1)
plt.clf()
plt.bar(df_prior['category'], df_prior['prior'])

plt.xlabel('Category')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Prior Probability')
plt.gca().set_axisbelow(True)
plt.grid(axis='y', alpha=0.5, zorder=0)
plt.tight_layout()
plt.show()
# Out:
#            category  count     prior
# 0          CLOTHING     28  0.023470
# 1         COMMUTING    103  0.086337
# 2     ENTERTAINMENT     91  0.076278
# 3              FOOD    442  0.370495
# 4            HEALTH     37  0.031014
# 5           HOBBIES     59  0.049455
# 6   HOUSEHOLD-ITEMS     67  0.056161
# 7         INVESTING     21  0.017603
# 8            LIVING     54  0.045264
# 9      OTHER-INCOME    103  0.086337
# 10           SALARY     26  0.021794
# 11       TECHNOLOGY    108  0.090528
# 12    UNCATEGORIZED     42  0.035205
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Word propabilies P(Word|Category)

# %%
receiver = df['receiver'].str.split(' ')
receiver = receiver.drop_duplicates()
[print(row) for row in receiver.values];
# Out:
# nan
# ['H', 'M']
# ['STADIUM']
# ['KLARNA', 'AB']
# ['CHF*PNTpay']
# ['HSL', 'Mobiili']
# ['VEIKKAUS', 'OY']
# ['DNA', 'Welho', 'Oy']
# ['VR-YHTYMÄ', 'OY']
# ['Vattenfall', 'Oy']
# ['APPLE.COM/BILL']
# ['TOPI', 'FEELGOOD', 'K']
# ['VALKOINEN', 'PUU', 'C']
# ['VFI*VEIKKAUS', 'OY']
# ['VERKKOKAUPPA.COM']
# ['RASMUS', 'HAAPANIEMI']
# ['STOCKMANN', 'TAPIOLA']
# ['SUOMEN', 'OSUUSPANKKI']
# ['CHF*Krkkinen', 'Web', 'Oy']
# ['K-Supermarket', 'Derby']
# ['KLARNA', 'BANK', 'AB', 'PUBL']
# ['VERIFONE', 'FINLAND', 'OY']
# ['A', 'MEDIUM', 'CORPORATION']
# ['ADOBE', 'PHOTOGPHY', 'PLAN']
# ['ALEPA', 'KIVISTON', 'ASEMA']
# ['CENTAURUS', 'FINLAND', 'KY']
# ['KATJAN', 'VOHVELIKAHVILA']
# ['Tekniikan', 'akateemiset']
# ['K-citymarket', 'Kauhajoki']
# ['Kauhajoen', 'Ege', 'Kebab', 'Pi']
# ['R_VANTAA_Safiirikuja', '7']
# ['SEPPÄLÄ', 'ANTTI', 'SAMULI']
# ['R_SEINAeJOKI_Valtionkatu']
# ['SEPPÄLÄ', 'SEIJA', 'TUULIKKI']
# ['Bestseller', 'AS', 'JJ_FI_3071_']
# ['Espoon', 'I', 'Tapiolan', 'apteekk']
# ['R_HELSINKI_Tripla_Asema_L']
# ['MOBILEPAY', 'KATARIINA', 'SEPPÄLÄ']
# ['MOBILEPAY', 'SANNA', 'MAARIT', 'MARJA', 'HEIKKIL']
# ['POLYTEKNIKKOJEN', 'PARTIOKLUBI', 'TEEPAKKI']
# ['Caruna', 'Oy']
# ['DISNEY', 'PLUS']
# ['PRISMA', 'SELLO']
# ['KLARNA', 'BANK', 'AB']
# ['VFI*BURGERI', '66']
# ['VFI*LI', 'CHEN', 'OY']
# ['K-Market', 'Perkkaa']
# ['Klarna*biltema.fi']
# ['SWEDAVIA', 'ARN', 'INFO']
# ['Subway', '65975', 'REDI']
# ['HMSHost', 'Finland', 'Oy']
# ['Studio', 'Hotel', 'Kista']
# ['K-market', 'Woikantori']
# ['PADDLE.NET*', 'ADGUARD']
# ['Arlanda', 'Walk', 'Through']
# ['M', 'Room', 'Panorama', 'Tower,']
# ['MTR', 'PENDELTAGEN', 'HELENE']
# ['VFI*LAIDASTA', 'LAITAAN', 'OY']
# ['OP', 'VÄHITTÄISASIAKKAAT', 'OYJ']
# ['HAAPANIEMI', 'RASMUS', 'ALEKSI', 'RIKHA']
# ['H&M']
# ['KELA']
# ['ABB', 'OY']
# ['DNA', 'Oyj']
# ['KABACKA']
# ['ICEYE', 'OY']
# ['KELA/FPA']
# ['TEEPAKKI']
# ['Ifolor', 'Oy']
# ['KIM', 'ARIMA']
# ['MOBILEPAY']
# ['SEO', 'Jaala']
# ['BESTSELLER']
# ['HOLY', 'SMOKE']
# ['SuitSupply']
# ['Mroom', 'Sello']
# ['TEEPAKKI', 'RY']
# ['MOB.PAY*RESQ']
# ['PAYTRAIL', 'OYJ']
# ['SUBWAY', 'AINOA']
# ['YA', 'Iso', 'Omena']
# ['Bestseller', 'AS']
# ['DRESSMANN', '740']
# ['Mroom', 'Tapiola']
# ['SILMIKKAIN', 'OY']
# ['SKLIROU', 'DANAI']
# ['Gigantti', 'Forum']
# ['S-MARKET', 'GRANI']
# ['SILMAASEMA', 'ISO']
# ['SOKOS', 'HELSINKI']
# ['STADIUM', 'OUTLET']
# ['AALTO', 'TIETOTEKN']
# ['BOWLCIRCUS', 'SELL']
# ['C', 'HOTEL', 'HELSINK']
# ['CAFE', 'KUUSIJARVI']
# ['CLAS', 'OHLSON', '217']
# ['CLAS', 'OHLSON', '257']
# ['Foodora', 'Finland']
# ['KOTIPIZZA', 'HELSI']
# ['KOTIPIZZA', 'ISO-O']
# ['LIDL', 'HKI', 'KAMPPI']
# ['POSTI', 'OY,', 'DIGIT']
# ['SUSANNAN', 'GRILLI']
# ['VFI*Alkanlar', 'Oy']
# ['VISION', 'ENTERPRI']
# ['XXL', 'FIN', '704', 'KLU']
# ['XXL', 'FIN', '716', 'RED']
# ['HAAPANIEMI', 'HANNU']
# ['NISSEN', 'ISO', 'OMENA']
# ['PRISMA', 'ISO', 'OMENA']
# ['SQUARESPACE', 'INC.']
# ['STARSHIP', 'ESTONIA']
# ['SVEA', 'PAYMENTS', 'OY']
# ['TRUSTLY', 'GROUP', 'AB']
# ['MOBILEPAY', 'JOONA', 'P']
# ['PARTIOAITTA', 'SELLO']
# ['ALKO', 'TAPIOLA', 'AINOA']
# ['Helsingin', 'kaupunki']
# ['K-market', 'Iso', 'Omena']
# ['KANSANELÄKELAITOS']
# ['Kauhajoen', 'kaupunki']
# ['PAYPAL', '*MECHBOARDS']
# ['QUALITY', 'TASTE', 'S.A.']
# ['RAVINTOLA', 'KUNINGAS']
# ['STOCKMANN', 'HELSINKI']
# ['Teknologforeningen']
# ['ALEPA', 'OTANIEMI', 'UUSI']
# ['CHECKOUT', 'FINLAND', 'OY']
# ['ESPRESSO', 'HOUSE', '1226']
# ['Fazer', 'Ravintolat', 'Oy']
# ['GRAMMARLY', 'CON7SVL22']
# ['GRAMMARLY', 'COZLBHUEC']
# ['Gigantti', 'Itaekeskus']
# ['PAYPAL', '*BIKECOMPONE']
# ['DRESSMANN', '707', 'KAMPPI']
# ['Kuva', 'Ahti', 'Oy', 'Fotoyks']
# ['LIDL', 'ESPOO', 'ISO', 'OMENA']
# ['Nintendo', 'CA778475780']
# ['K-supermarket', 'Tapiola']
# ['LIDL', 'ESPOO-LAAJALAHTI']
# ['PARTIOAITTA', 'ISO', 'OMENA']
# ['R', 'AALTOYO', 'METROKESKUS']
# ['SUUPOHJAN', 'OSUUSPANKKI']
# ['AMZN', 'Mktp', 'DE*2E0PE6IM4']
# ['Aalto', 'Kvarkki', 'FI139965']
# ['Subway', '57389', 'Espoo', 'Iso']
# ['Teboil', 'Kaivoksela', '7038']
# ['VFI*Teknologforeningen']
# ['MOB.PAY*BENJAMIN', 'KYNGAS']
# ['MOBILEPAY', 'OSKAR', 'CONNELL']
# ['MOBILEPAY', 'PYRY', 'MESKANEN']
# ['TEEKKARISUUNNISTAJAT', 'RY']
# ['Compass', 'Group', 'Finland', 'Oy']
# ['MOB.PAY*ELIAS', 'YL$-JARKKO']
# ['VFI*HINTAKAARI', 'KALALAHTI']
# ['0448', 'NESTE', 'HEINOLA', 'VIERUM']
# ['928', 'RUSTA', 'HELSINKI', '-', 'LANT']
# ['ALKO', 'ESPOO', 'OTANIEMI', 'ML', '21']
# ['AMZN', 'MKTP', 'DE*2R4EA2EG4', 'AM']
# ['Avecra', 'Oy', 'Stop', 'at', 'station']
# ['Bestseller', 'AS', 'JJ-VM_FI_40']
# ['Galaxie', 'Center', '&', 'Waino', 'Se']
# ['K-CITYMARKET', 'ESPOO', 'ISO', 'OM']
# ['K-CITYMARKET', 'HELSINKI', 'RUO']
# ['K-citymarket', 'Espoo', 'Leppav']
# ['MOB.PAY*KAISA', 'MAARET', 'KUKK']
# ['MOB.PAY*VISA', 'AHTI', 'ELIAS', 'O']
# ['NETFLIX', 'INTERNATIONAL', 'B.V']
# ['R', 'HKI', 'LAIVALAHDENPORTTI', '3']
# ['VFI*TMK', 'Tori', 'ja', 'markkinak']
# ['TF', 'BANK', 'AB,', 'FILIAL', 'FINLAND']
# ['MOBILEPAY', 'ANTTI', 'TERÄSVALLI']
# ['MOBILEPAY', 'JOHANNA', 'SEPPÄLÄ']
# ['MOBILEPAY', 'OLIVER', 'HIEKKAMIES']
# ['MOBILEPAY', 'SAARA', 'MARIA', 'PIESKI']
# ['MOBILEPAY', 'KALLE', 'HERMAN', 'KEINONEN']
# ['Aalto-yliopiston', 'ylioppilaskunta']
# ['HELSINGIN', 'YLIOPISTON', 'PARTIOLAISET', 'HY']
# ['HELSINGIN', 'YLIOPISTON', 'PARTIOLAISET', 'RY']
# ['VFI*Adomex']
# ['DNA', 'WELHO', 'OY']
# ['NISSEN', 'SELLO']
# ['VEROHALLINTO']
# ['ABC', 'VAAJAKOSKI']
# ['CLAS', 'OHLSON', '50']
# ['CLAS', 'OHLSON', '57']
# ['CLAS', 'OHLSON', '236']
# ['KOTIPIZZA', 'SELLO']
# ['MCD', 'NIITTYKUMPU']
# ['VFI*SKY', 'EXPRESS']
# ['ABC', 'KELJONKANGAS']
# ['K-market', 'Maununneva']
# ['CENTAURUS', 'FINLAND', 'OY']
# ['IKEA', 'VANTAA', 'RAVINTOLA']
# ['BUFFA', 'PRISMA', 'HAMEENLINNA']
# ['Avecra', 'Oy', '28709', 'ravintola']
# ['IKEA', 'ESPOO', 'ITSEPALVELUKAS']
# ['NESTE', 'EXPRESS', 'ESPOO', 'OTAN.']
# ['SUOMEN', 'VAHINKOVAKUUTUS', 'OY']
# ['Subway', 'Espoo', 'Otaniemi', 'Aal']
# ['AALTO-YLIOPISTON', 'YLIOPPILASKUNTA', '-']
# ['POSTI', 'OY']
# ['Vattenfall']
# ['HAAPANIEMI', 'RASMUS']
# ['Rasmus', 'Haapaniemi']
# ['POHJOLA', 'VAKUUTUS', 'OY']
# ['FI35', '5780', '0786', '6157', '60']
# ['CLAS', 'OHLSON', '50', '', '', '', '', '', 'ESPOO']
# ['IKEA', 'OY', 'ECOMM', '', '', '', '', '', '', 'ESPOO']
# ['K-Supermarket', 'Derby', 'Espoo']
# ['K-citymarket', 'Espoo', '', 'ESPOO']
# ['Klarna*lensway.fi', '', '', 'KISTA']
# ['Klarna*veke.fi', '', '', '', '', '', 'Ranua']
# ['NISSEN', 'SELLO', '', '', '', '', '', '', '', 'ESPOO']
# ['PRISMA', 'SELLO', '', '', '', '', '', '', '', 'ESPOO']
# ['TOKMANNI', 'ESPOO', 'SELL', 'ESPOO']
# ['ALEPA', 'KIVISTON', 'ASEM', 'VANTAA']
# ['As.', 'Oy', 'Helsingin', 'Laventeli']
# ['Gigantti.fi', '', '', '', '', '', '', '', '', 'Vantaa']
# ['IKEA', 'VANTAA', 'HFB', 'MAI', 'VANTAA']
# ['IKEA', 'VANTAA', 'IF', 'CUST', 'VANTAA']
# ['K-Rauta', '75', '', '', '', '', '', '', '', '', '', 'VANTAA']
# ['R_VANTAA_Safiirikuj', 'VANTAA']
# ['CHF*www.kalusteweb.', 'TAMPERE']
# ['440', 'KOTIPIZZA', 'V', '', '', '', '', 'Helsinki']
# ['7802', 'Express', 'Makkyl', 'HELSINKI']
# ['Avecra', 'Oy', 'Ravintola', 'Helsinki']
# ['CLAS', 'OHLSON', '35', '', '', '', '', '', 'HELSINKI']
# ['Gigantti', 'Itaekeskus', 'Helsinki']
# ['K-citymarket', 'Easton', 'HELSINKI']
# ['K-market', 'Aurinkolah', 'Helsinki']
# ['K-market', 'Kotikontu', '', 'HELSINKI']
# ['K-supermarket', 'Vuosa', 'Helsinki']
# ['Klarna*tokmanni.fi', '', 'Mantsala']
# ['MOB.PAY*SANNA', 'MAARI', 'HELSINKI']
# ['MOBILEPAY', '', '', '', '', '', '', '', '', '', '', 'HELSINKI']
# ['VFI*VEIKKAUS', 'OY', '', '', '', '', 'HELSINKI']
# ['AMZN', 'MKTP', 'DE*LW1TC8', 'AMAZON.DE']
# ['K-citymarket', 'Kauhaj', 'KAUHAJOKI']
# ['STADIUM', 'OUTLET', '', '', '', '', '', 'SEINAJOKI']
# ['TOKMANNI', 'COLUMBUS', 'H', 'HESLSINKI']
# ['TOKMANNI', 'KAUHAJOKI', '', 'KAUHAJOKI']
# ['A', 'MEDIUM', 'CORPORATIO', '4155085008']
# ['APPLE.COM/BILL', '', '', '', '', '', 'ITUNES.COM']
# ['ADOBE', 'SYSTEMS', 'SOFTW', '044-207-3650']
# ['Mol*KahviKaveri', 'OY', '', '358753257553']
# ['KIASMA']
# ['KANRESTA', 'OY']
# ['NISSEN', 'ITIS']
# ['MOB.PAY*KIRA']
# ['VFI*Baoyu', 'Oy']
# ['FINNKINO', 'ITIS']
# ['VATTENFALL', 'OY']
# ['Espoon', 'kaupunki']
# ['POWER', 'SELLO', 'ESPOO']
# ['PAYPAL', '*ETSYIRELAND']
# ['TOKMANNI', 'HELSINKI', 'KAARI']
# ['ALKO', 'HKI', 'KANNELMAKI', 'PRISM']
# ['K-CITYMARKET', 'ESPOO', 'LEPPAV']
# ['HAAPANIEMI', 'RASMUS', 'ALEKSI', 'RIKHARD']
# ['NORDNET', 'BANK', 'AB', 'SUOMEN', 'SIVULIIKE']
# ['TEKNIIKAN', 'AKATEEMISET,', '00520,', 'HELSIN']
# ['AXA']
# ['Helen', 'Oy']
# ['OSUUSPANKKI']
# ['STIO', 'Oy', 'Helsinki']
# ['HSL', 'Mobiili', '', '', '', '', '', '', '', '', 'HSL']
# ['MobilePay', 'Jukka', 'Meskanen']
# ['AS', 'Oy', 'Helsingin', 'Laventeli']
# ['K-supermarket', 'Ivalo', 'Inari']
# ['S-MARKET', 'IVALO', '', '', '', '', '', 'IVALO']
# ['VFI*MARCANTE', 'OY', '', '', '', '', 'SIPOO']
# ['KOTIPIZZA', 'KIVIS', '', '', '', '', 'Vantaa']
# ['WWW.ROSEVERSAND.DE', '', 'BOCHOLT']
# ['Avecra', 'Oy', '26712', 'rav', 'Helsinki']
# ['Avecra', 'Oy/Aseman', 'Wu', 'Helsinki']
# ['FISKARS', 'FINLAND', 'OY', '', 'Helsinki']
# ['FREGATTA', 'OY', '', '', '', '', '', '', '', '', 'HELSINKI']
# ['Instrumentarium', 'Col', 'Helsinki']
# ['JYSK', 'VUOSAARI', '', '', '', '', '', '', 'HELSINKI']
# ['Lasten', 'Paivan', 'Saati', 'Helsinki']
# ['Linnanmaki', '', '', '', '', '', '', '', '', '', 'Helsinki']
# ['R_HELSINKI_Sornaine', 'HELSINKI']
# ['R_HELSINKI_Vuotie', '4', 'HELSINKI']
# ['S-MARKET', 'HELSINKI', '', '', 'HELSINKI']
# ['SPR', 'KONTTI', 'HELS', '', '', '', '', 'HELSINKI']
# ['VFI*FOOD', 'CHEF', '', '', '', '', '', '', 'HELSINKI']
# ['KAUNISPAAN', 'HUIP', '', '', '', '', 'Saariselka']
# ['TANKAVAARAN', 'RAVINTO', 'TANKAVAARA']
# ['COOP', 'PRIX', 'KJOLLEFJO', 'KJOLLEFJORD']
# ['CARUNA', 'OY']
# ['KOTIPIZZA', 'KIVIS']
# ['PIZZERIA', 'PIIKKI']
# ['LUCKIEFUN', 'S', 'SEINAJOKI', 'IDE']
# ['MOB.PAY*SANNA', 'MAARIT', 'MARJ']
# ['Klarna', 'AB']
# ['Kiineistöhuolto', 'MAK', 'Oy']
# ['MobilePay', 'Teemu', 'Takanen']
# ['Kiinteistöhuolto', 'MAK', 'Ou']
# ['JAALAN', 'KYLEKAUPPA', 'J', 'JAALA']
# ['SEO', 'Jaala', '', '', '', '', '', '', '', '', '', '', 'Elimaki']
# ['ALKO', 'HKI', 'VUOSAARI', 'C', 'HELSINKI']
# ['JEDEDUDET', 'OY', '', '', '', '', '', '', '', 'HELSINKI']
# ['KURRA', 'OY', '', '', '', '', '', '', '', '', '', '', '', 'HELSINKI']
# ['M', 'Room', 'Itis,', 'Helsin', 'Helsinki']
# ['PRISMA', 'HERTTONIEMI', '', 'HELSINKI']
# ['R_HELSINKI_Kaiasata', 'HELSINKI']
# ['S-MARKET', 'COLUMBUS', '', '', 'HELSINKI']
# ['VALLISAAREN', 'SATAMAK', 'HELSINKI']
# ['MobilePay', 'Sanna', 'Maarit', 'Marja', 'Heikkilä']
# ['HEMTEX', '440']
# ['FITNESSGYM', 'OY']
# ['AKATEEMINEN', 'KIR']
# ['OUTIN', 'LOUNAS-BU']
# ['VFI*FINNBALL', 'OY']
# ['IM*', 'KEYCHRON.COM']
# ['NISSEN', 'LASIPALATSI']
# ['Espoon', '10.', 'apteekki']
# ['VFI*RATIKKA', 'GROUP', 'OY']
# ['K-supermarket', 'Leppavaara']
# ['AALTO-KORKEAKOULUSÄÄTIÖ']
# ['Paytrail', 'Oyj']
# ['VR-YHTYMÄ', 'OYJ']
# ['Telia', 'Finland', 'Oyj']
# ['APPLE.COM/BILL', '', '', '', '', '', 'CORK']
# ['IKEA', 'VANTAA', 'HFB', 'ECO', 'VANTAA']
# ['STADIUM', 'JUMBO', '3', '', '', '', '', 'VANTAA']
# ['STOCKMANN', 'JUMBO', '', '', '', '', 'VANTAA']
# ['SP', 'KIEKKOKINGI', '', '', '', '', '', 'KAARINA']
# ['Compass', 'Group', 'Finla', 'Helsinki']
# ['Karisman', 'Suutari', '', '', '', 'HELSINKI']
# ['LIDL', 'HELSINKI-COLUM', 'HELSINKI']
# ['RAZ', 'KY', '', '', '', '', '', '', '', '', '', '', '', '', '', 'HELSINKI']
# ['STOCKMANN', 'HELSINKI', '', 'HELSINKI']
# ['SUBWAY', '41596', 'Helsin', 'Helsinki']
# ['Saiturinporssi', 'Colu', 'Helsinki']
# ['SuitSupply', '', '', '', '', '', '', '', '', '', 'Helsinki']
# ['Vuosaaren', 'Urheiluta', 'HELSINKI']
# ['PRISMA', 'TRIPLA']
# ['J.P.', 'Kioskit', 'Oy']
# ['K-market', 'Kotikontu']
# ['RAVINTOLA', 'KONNICHIWA']
# ['ALKO', 'HELSINKI', 'ARKADIA']
# ['MOBILEPAY', 'TEEMU', 'KUUSISTO']
# ['OLHUS', 'KOBENHAVN', 'HELSINKI']
# ['OLHUS', 'STOCKHOLM', 'HELSINKI']
# ['ALKO', 'ESPOO', 'LEPPAVAARA', 'SEL']
# ['POP', 'Vakuutus']
# ['SPORT', 'CORNER']
# ['ENJOY', 'KITCHEN', '&']
# ['VFI*AMOS', 'REX', 'AB']
# ['AMAZON.DE', 'AMAZON.DE']
# ['DeliSis', 'Oy', 'Cafe', 'Lasikello']
# ['IZETTLE', 'AS', 'PAYPAL', 'SERVICE']
# ['DRESSMANN', '712']
# ['Gigantti', 'Oy', 'Ab']
# ['Delishus', 'Services']
# ['IKEA', 'VANTAA', 'KIOSK']
# ['Casino', 'Helsinki', '-', '1280']
# ['IKEA', 'VANTAA', 'IF', 'CUSTOMER', 'R']

# %%
receiver = df.loc[df['category'] == 'FOOD', 'receiver']
receiver = receiver.drop_duplicates().reset_index(drop=True)
receiver = receiver.to_list()
[print(row) for row in receiver];
print(len(receiver))
# Out:
# VALKOINEN PUU C
# VFI*VEIKKAUS OY
# K-Supermarket Derby
# ALEPA KIVISTON ASEMA
# KATJAN VOHVELIKAHVILA
# K-citymarket Kauhajoki
# Kauhajoen Ege Kebab Pi
# R_VANTAA_Safiirikuja 7
# R_SEINAeJOKI_Valtionkatu
# R_HELSINKI_Tripla_Asema_L
# nan
# PRISMA SELLO
# VFI*BURGERI 66
# K-Market Perkkaa
# Subway 65975 REDI
# K-market Woikantori
# Arlanda Walk Through
# MOBILEPAY
# MOB.PAY*RESQ
# PAYTRAIL OYJ
# SUBWAY AINOA
# S-MARKET GRANI
# AALTO TIETOTEKN
# Foodora Finland
# LIDL HKI KAMPPI
# PRISMA ISO OMENA
# STARSHIP ESTONIA
# K-market Iso Omena
# RAVINTOLA KUNINGAS
# Teknologforeningen
# ALEPA OTANIEMI UUSI
# ESPRESSO HOUSE 1226
# Fazer Ravintolat Oy
# LIDL ESPOO ISO OMENA
# K-supermarket Tapiola
# LIDL ESPOO-LAAJALAHTI
# R AALTOYO METROKESKUS
# Aalto Kvarkki FI139965
# Teboil Kaivoksela 7038
# VFI*Teknologforeningen
# MOB.PAY*BENJAMIN KYNGAS
# Compass Group Finland Oy
# MOB.PAY*ELIAS YL$-JARKKO
# Avecra Oy Stop at station
# K-CITYMARKET ESPOO ISO OM
# K-CITYMARKET HELSINKI RUO
# K-citymarket Espoo Leppav
# MOB.PAY*KAISA MAARET KUKK
# R HKI LAIVALAHDENPORTTI 3
# ABC KELJONKANGAS
# K-market Maununneva
# K-Supermarket Derby Espoo
# PRISMA SELLO        ESPOO
# ALEPA KIVISTON ASEM VANTAA
# R_VANTAA_Safiirikuj VANTAA
# 440 KOTIPIZZA V     Helsinki
# Avecra Oy Ravintola Helsinki
# K-market Aurinkolah Helsinki
# K-market Kotikontu  HELSINKI
# K-supermarket Vuosa Helsinki
# MOBILEPAY           HELSINKI
# VFI*VEIKKAUS OY     HELSINKI
# K-citymarket Kauhaj KAUHAJOKI
# FINNKINO ITIS
# CAFE KUUSIJARVI
# ALKO HKI KANNELMAKI PRISM
# K-CITYMARKET ESPOO LEPPAV
# K-supermarket Ivalo Inari
# S-MARKET IVALO      IVALO
# Avecra Oy 26712 rav Helsinki
# FREGATTA OY         HELSINKI
# R_HELSINKI_Sornaine HELSINKI
# R_HELSINKI_Vuotie 4 HELSINKI
# S-MARKET HELSINKI   HELSINKI
# TOKMANNI COLUMBUS H HESLSINKI
# JAALAN KYLEKAUPPA J JAALA
# ALKO HKI VUOSAARI C HELSINKI
# PRISMA HERTTONIEMI  HELSINKI
# R_HELSINKI_Kaiasata HELSINKI
# S-MARKET COLUMBUS   HELSINKI
# OUTIN LOUNAS-BU
# K-supermarket Leppavaara
# Compass Group Finla Helsinki
# LIDL HELSINKI-COLUM HELSINKI
# RAZ KY              HELSINKI
# SUBWAY 41596 Helsin Helsinki
# PRISMA TRIPLA
# K-market Kotikontu
# ALKO HELSINKI ARKADIA
# ALKO ESPOO LEPPAVAARA SEL
# Delishus Services
# IKEA VANTAA KIOSK
# IKEA VANTAA IF CUSTOMER R
# 93

# %%
[re.split(';|,|-|_|\*|\s', str(row).lower()) for row in receiver]
# Out:
# [['valkoinen', 'puu', 'c'],
#  ['vfi', 'veikkaus', 'oy'],
#  ['k', 'supermarket', 'derby'],
#  ['alepa', 'kiviston', 'asema'],
#  ['katjan', 'vohvelikahvila'],
#  ['k', 'citymarket', 'kauhajoki'],
#  ['kauhajoen', 'ege', 'kebab', 'pi'],
#  ['r', 'vantaa', 'safiirikuja', '7'],
#  ['r', 'seinaejoki', 'valtionkatu'],
#  ['r', 'helsinki', 'tripla', 'asema', 'l'],
#  ['nan'],
#  ['prisma', 'sello'],
#  ['vfi', 'burgeri', '66'],
#  ['k', 'market', 'perkkaa'],
#  ['subway', '65975', 'redi'],
#  ['k', 'market', 'woikantori'],
#  ['arlanda', 'walk', 'through'],
#  ['mobilepay'],
#  ['mob.pay', 'resq'],
#  ['paytrail', 'oyj'],
#  ['subway', 'ainoa'],
#  ['s', 'market', 'grani'],
#  ['aalto', 'tietotekn'],
#  ['foodora', 'finland'],
#  ['lidl', 'hki', 'kamppi'],
#  ['prisma', 'iso', 'omena'],
#  ['starship', 'estonia'],
#  ['k', 'market', 'iso', 'omena'],
#  ['ravintola', 'kuningas'],
#  ['teknologforeningen'],
#  ['alepa', 'otaniemi', 'uusi'],
#  ['espresso', 'house', '1226'],
#  ['fazer', 'ravintolat', 'oy'],
#  ['lidl', 'espoo', 'iso', 'omena'],
#  ['k', 'supermarket', 'tapiola'],
#  ['lidl', 'espoo', 'laajalahti'],
#  ['r', 'aaltoyo', 'metrokeskus'],
#  ['aalto', 'kvarkki', 'fi139965'],
#  ['teboil', 'kaivoksela', '7038'],
#  ['vfi', 'teknologforeningen'],
#  ['mob.pay', 'benjamin', 'kyngas'],
#  ['compass', 'group', 'finland', 'oy'],
#  ['mob.pay', 'elias', 'yl$', 'jarkko'],
#  ['avecra', 'oy', 'stop', 'at', 'station'],
#  ['k', 'citymarket', 'espoo', 'iso', 'om'],
#  ['k', 'citymarket', 'helsinki', 'ruo'],
#  ['k', 'citymarket', 'espoo', 'leppav'],
#  ['mob.pay', 'kaisa', 'maaret', 'kukk'],
#  ['r', 'hki', 'laivalahdenportti', '3'],
#  ['abc', 'keljonkangas'],
#  ['k', 'market', 'maununneva'],
#  ['k', 'supermarket', 'derby', 'espoo'],
#  ['prisma', 'sello', '', '', '', '', '', '', '', 'espoo'],
#  ['alepa', 'kiviston', 'asem', 'vantaa'],
#  ['r', 'vantaa', 'safiirikuj', 'vantaa'],
#  ['440', 'kotipizza', 'v', '', '', '', '', 'helsinki'],
#  ['avecra', 'oy', 'ravintola', 'helsinki'],
#  ['k', 'market', 'aurinkolah', 'helsinki'],
#  ['k', 'market', 'kotikontu', '', 'helsinki'],
#  ['k', 'supermarket', 'vuosa', 'helsinki'],
#  ['mobilepay', '', '', '', '', '', '', '', '', '', '', 'helsinki'],
#  ['vfi', 'veikkaus', 'oy', '', '', '', '', 'helsinki'],
#  ['k', 'citymarket', 'kauhaj', 'kauhajoki'],
#  ['finnkino', 'itis'],
#  ['cafe', 'kuusijarvi'],
#  ['alko', 'hki', 'kannelmaki', 'prism'],
#  ['k', 'citymarket', 'espoo', 'leppav'],
#  ['k', 'supermarket', 'ivalo', 'inari'],
#  ['s', 'market', 'ivalo', '', '', '', '', '', 'ivalo'],
#  ['avecra', 'oy', '26712', 'rav', 'helsinki'],
#  ['fregatta', 'oy', '', '', '', '', '', '', '', '', 'helsinki'],
#  ['r', 'helsinki', 'sornaine', 'helsinki'],
#  ['r', 'helsinki', 'vuotie', '4', 'helsinki'],
#  ['s', 'market', 'helsinki', '', '', 'helsinki'],
#  ['tokmanni', 'columbus', 'h', 'heslsinki'],
#  ['jaalan', 'kylekauppa', 'j', 'jaala'],
#  ['alko', 'hki', 'vuosaari', 'c', 'helsinki'],
#  ['prisma', 'herttoniemi', '', 'helsinki'],
#  ['r', 'helsinki', 'kaiasata', 'helsinki'],
#  ['s', 'market', 'columbus', '', '', 'helsinki'],
#  ['outin', 'lounas', 'bu'],
#  ['k', 'supermarket', 'leppavaara'],
#  ['compass', 'group', 'finla', 'helsinki'],
#  ['lidl', 'helsinki', 'colum', 'helsinki'],
#  ['raz', 'ky', '', '', '', '', '', '', '', '', '', '', '', '', '', 'helsinki'],
#  ['subway', '41596', 'helsin', 'helsinki'],
#  ['prisma', 'tripla'],
#  ['k', 'market', 'kotikontu'],
#  ['alko', 'helsinki', 'arkadia'],
#  ['alko', 'espoo', 'leppavaara', 'sel'],
#  ['delishus', 'services'],
#  ['ikea', 'vantaa', 'kiosk'],
#  ['ikea', 'vantaa', 'if', 'customer', 'r']]

# %% [markdown]
# # Gaussian Amount distribution

# %%
df_gaussian = df.loc[df['receiver'].notnull()].copy()
#df_gaussian['amount'] = np.power(df_gaussian['amount'], 3)
df_gaussian = df_gaussian.groupby(['category']).agg(count=('category', 'count'),
                                      mean=('amount', 'mean'),
                                      std=('amount', 'std')).reset_index()

display(df_gaussian)

plt.figure()
plt.clf()
x = np.linspace(-1000, 1000, 100)
[plt.plot(x, stats.norm.pdf(x, df_gaussian['mean'][i], df_gaussian['std'][i]), label=f"{df_gaussian['category'][i]}") for i in df_gaussian.index];
plt.legend()
plt.show()
# Out:
#            category  count         mean         std
# 0          CLOTHING     25  -110.441200  204.865770
# 1         COMMUTING    100   -17.630600   22.229108
# 2     ENTERTAINMENT     87   -14.456552   18.644449
# 3              FOOD    435   -15.160851   17.860864
# 4            HEALTH     34   -50.389706   90.421548
# 5           HOBBIES     56   -74.509107  163.035254
# 6   HOUSEHOLD-ITEMS     64  -120.490469  271.793276
# 7         INVESTING     18  -677.777778  606.392957
# 8            LIVING     51  -357.997059  392.121206
# 9      OTHER-INCOME     98   154.524286  356.266622
# 10           SALARY     23  2124.525217  730.622623
# 11       TECHNOLOGY    105   -48.622476  150.268253
# 12    UNCATEGORIZED     34   -59.767059   64.885041
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
